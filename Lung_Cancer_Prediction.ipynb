# %%
# Import necessary libraries
import pandas as pd  # Import pandas for data manipulation
import numpy as np   # Import numpy for numerical operations
import matplotlib.pyplot as plt   # Import matplotlib for data visualization
import seaborn as sns   # Import seaborn for enhanced data visualization

# Read data from a CSV file into a Pandas DataFrame
data = pd.read_csv('/content/survey lung cancer.csv')

# Create a DataFrame named 'df' to store the imported data
df = pd.DataFrame(data)

# %%
# Display information about the DataFrame 'df'
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
#  15  LUNG_CANCER            309 non-null    object
# dtypes: int64(14), object(2)
# memory usage: 38.8+ KB

# %%
df_lung_cancer = df[df["LUNG_CANCER"]=='YES']
sns.countplot(df_lung_cancer["ANXIETY"])
plt.title("Anxiety in people with cancer")
plt.xticks([0, 1], ('No', 'Yes'))
plt.show()
print("YES = 142")
print("NO = 128")
# Out:
# YES = 142
# NO = 128

# %%
df.head(6)
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
# 5      F   75        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
# 5                2         2         2         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 0                    2                      2           2         YES
# 1                    2                      2           2         YES
# 2                    2                      1           2          NO
# 3                    1                      2           2          NO
# 4                    2                      1           1          NO
# 5                    2                      1           1         YES

# %%
df.shape
# Out:
# (309, 16)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0        M   69        1               2        2              1
# 1        M   74        2               1        1              1
# 2        F   59        1               1        1              2
# 3        M   63        2               2        2              1
# 4        F   63        1               2        1              1
# ..     ...  ...      ...             ...      ...            ...
# 304      F   56        1               1        1              2
# 305      M   70        2               1        1              1
# 306      M   58        2               1        1              1
# 307      M   67        2               1        2              1
# 308      M   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# 1                  2         2         2         1                  1
# 2                  1         2         1         2                  1
# 3                  1         1         1         1                  2
# 4                  1         1         1         2                  1
# ..               ...       ...       ...       ...                ...
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 0           2                    2                      2           2
# 1           1                    2                      2           2
# 2           2                    2                      1           2
# 3           1                    1                      2           2
# 4           2                    2                      1           1
# ..        ...                  ...                    ...         ...
# 304         2                    2                      2           1
# 305         2                    2                      1           2
# 306         2                    1                      1           2
# 307         2                    2                      1           2
# 308         1                    1                      2           1
#
#     LUNG_CANCER
# 0           YES
# 1           YES
# 2            NO
# 3            NO
# 4            NO
# ..          ...
# 304         YES
# 305         YES
# 306         YES
# 307         YES
# 308         YES
#
# [309 rows x 16 columns]>

# %%
sns.countplot(df["SMOKING"])
# Out:
# <Axes: ylabel='count'>

# %%
plt.figure(figsize=(5,4))
sns.lineplot(x=df["ANXIETY"], y=df["LUNG_CANCER"])
plt.title("ANXIETY vs LUNG_CANCER", size=20)
plt.show()

# %%
colum_cat = ['GENDER','LUNG_CANCER']
for i in colum_cat:
    print('-------------------------')
    print(df[i].value_counts())
    print('-------------------------')
# Out:
# -------------------------
# M    162
# F    147
# Name: GENDER, dtype: int64
# -------------------------
# -------------------------
# YES    270
# NO      39
# Name: LUNG_CANCER, dtype: int64
# -------------------------

# %%
df_clean = df.copy()
for i in colum_cat:
    print(f'Catagory of {i}')
    catlist = df_clean[i].unique()
    for j, val in enumerate(catlist):
         dftobjfinal = df_clean[i].replace({val:j},inplace=True)
         #print(dftobjfinal)
         print(j,val)
    print('--------------------------------')
# Out:
# Catagory of GENDER
# 0 M
# 1 F
# --------------------------------
# Catagory of LUNG_CANCER
# 0 YES
# 1 NO
# --------------------------------

# %%
df_clean
# Out:
#      GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0         0   69        1               2        2              1
# 1         0   74        2               1        1              1
# 2         1   59        1               1        1              2
# 3         0   63        2               2        2              1
# 4         1   63        1               2        1              1
# ..      ...  ...      ...             ...      ...            ...
# 304       1   56        1               1        1              2
# 305       0   70        2               1        1              1
# 306       0   58        2               1        1              1
# 307       0   67        2               1        2              1
# 308       0   62        1               1        1              2
#
#      CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  \
# 0                  1         2         1         2                  2
# 1                  2         2         2         1                  1
# 2                  1         2         1         2                  1
# 3                  1         1         1         1                  2
# 4                  1         1         1         2                  1
# ..               ...       ...       ...       ...                ...
# 304                2         2         1         1                  2
# 305                1         2         2         2                  2
# 306                1         1         2         2                  2
# 307                1         2         2         1                  2
# 308                1         2         2         2                  2
#
#      COUGHING  SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  \
# 0           2                    2                      2           2
# 1           1                    2                      2           2
# 2           2                    2                      1           2
# 3           1                    1                      2           2
# 4           2                    2                      1           1
# ..        ...                  ...                    ...         ...
# 304         2                    2                      2           1
# 305         2                    2                      1           2
# 306         2                    1                      1           2
# 307         2                    2                      1           2
# 308         1                    1                      2           1
#
#      LUNG_CANCER
# 0              0
# 1              0
# 2              1
# 3              1
# 4              1
# ..           ...
# 304            0
# 305            0
# 306            0
# 307            0
# 308            0
#
# [309 rows x 16 columns]

# %%
#Data Visualization
plt.figure(figsize=(10,6))
sns.countplot(df["SMOKING"])
plt.title("SMOKING", size=10)
plt.show()

# %%
plt.figure(figsize = (12,10), dpi=100)
ax = plt.axes()
sns.heatmap(df.corr(), annot = True, cmap='GnBu', ax=ax)
ax.set_title('Correlation Matrix - Before Encoding & Handling Missing Data', weight='bold')
plt.show()
# Out:
# <ipython-input-144-d0e246d9fdee>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True, cmap='GnBu', ax=ax)

# %%
from sklearn.neighbors import LocalOutlierFactor
clf = LocalOutlierFactor()
y_pred = clf.fit_predict(df_clean)

# %%
x_score = clf.negative_outlier_factor_
outlier_score = pd.DataFrame()
outlier_score["score"] = x_score

#threshold
threshold2 = -1.5
filtre2 = outlier_score["score"] < threshold2
outlier_index = outlier_score[filtre2].index.tolist()

# %%
len(outlier_index)
# Out:
# 6

# %%
df_clean = df.copy()

# %%
g = df_clean.groupby('LUNG_CANCER')
df_balanced = g.apply(lambda x: x.sample(g.size().min()).reset_index(drop=True))
df_balanced = df_balanced.reset_index(drop=True)
x = df_balanced[['SMOKING','PEER_PRESSURE','ALCOHOL CONSUMING']]
y = df_balanced['LUNG_CANCER'].map({'YES': 1, 'NO': 0})

# %%
x
# Out:
#     SMOKING  PEER_PRESSURE  ALCOHOL CONSUMING
# 0         1              2                  1
# 1         1              1                  1
# 2         1              2                  2
# 3         2              1                  1
# 4         1              1                  1
# ..      ...            ...                ...
# 73        2              2                  2
# 74        2              2                  2
# 75        2              1                  2
# 76        2              2                  2
# 77        1              1                  2
#
# [78 rows x 3 columns]

# %%
y
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 73    1
# 74    1
# 75    1
# 76    1
# 77    1
# Name: LUNG_CANCER, Length: 78, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.40, random_state = 42, shuffle=True)

# %%
from sklearn.ensemble import RandomForestClassifier
r_forest = RandomForestClassifier(criterion = 'entropy', max_depth = 20, n_estimators = 10000)
r_forest.fit(x_train,y_train)
predicted = r_forest.predict(x_test)
score = r_forest.score(x_test, y_test)
rf_score_ = np.mean(score)

print('Accuracy : %.3f' % (rf_score_))
# Out:
# Accuracy : 0.844

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

logmodel= LogisticRegression()
logmodel.fit(x_train,y_train)

predictions=logmodel.predict(x_test)
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.88      0.82        16
#            1       0.86      0.75      0.80        16
#
#     accuracy                           0.81        32
#    macro avg       0.82      0.81      0.81        32
# weighted avg       0.82      0.81      0.81        32

# %%
from tensorflow.keras.layers import Conv1D, Dense, Input, MaxPooling1D, Dropout, Flatten
from tensorflow.keras.models import Sequential

model_cnn = Sequential()

model_cnn.add(Dense(3, activation='relu'))
model_cnn.add(Dense(10, activation='relu'))
model_cnn.add(Dense(1, activation='sigmoid'))

model_cnn.compile(loss='binary_crossentropy', optimizer='adam', metrics='accuracy')

# %%
import tensorflow as tf
from tensorflow import keras
#es=tf.keras.callbacks.EarlyStopping(
#    min_delta=0.001,
#    patience=10,
#    restore_best_weights=True
h_cnn = model_cnn.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100)
model_cnn.summary()
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 146ms/step - loss: 0.6976 - accuracy: 0.5000 - val_loss: 0.6738 - val_accuracy: 0.5000
# Epoch 2/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.6953 - accuracy: 0.5000 - val_loss: 0.6722 - val_accuracy: 0.5000
# Epoch 3/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.6940 - accuracy: 0.5000 - val_loss: 0.6705 - val_accuracy: 0.5000
# Epoch 4/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.6917 - accuracy: 0.5000 - val_loss: 0.6691 - val_accuracy: 0.5000
# Epoch 5/100
# 2/2 [==============================] - 0s 70ms/step - loss: 0.6896 - accuracy: 0.5000 - val_loss: 0.6677 - val_accuracy: 0.5000
# Epoch 6/100
# 2/2 [==============================] - 0s 67ms/step - loss: 0.6879 - accuracy: 0.5000 - val_loss: 0.6663 - val_accuracy: 0.5000
# Epoch 7/100
# 2/2 [==============================] - 0s 75ms/step - loss: 0.6863 - accuracy: 0.5000 - val_loss: 0.6650 - val_accuracy: 0.5000
# Epoch 8/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.6843 - accuracy: 0.5000 - val_loss: 0.6637 - val_accuracy: 0.5000
# Epoch 9/100
# 2/2 [==============================] - 0s 111ms/step - loss: 0.6829 - accuracy: 0.5000 - val_loss: 0.6623 - val_accuracy: 0.5000
# Epoch 10/100
# 2/2 [==============================] - 0s 54ms/step - loss: 0.6818 - accuracy: 0.5000 - val_loss: 0.6611 - val_accuracy: 0.5000
# Epoch 11/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.6803 - accuracy: 0.5000 - val_loss: 0.6600 - val_accuracy: 0.5000
# Epoch 12/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.6786 - accuracy: 0.5000 - val_loss: 0.6589 - val_accuracy: 0.5000
# Epoch 13/100
# 2/2 [==============================] - 0s 181ms/step - loss: 0.6770 - accuracy: 0.5000 - val_loss: 0.6580 - val_accuracy: 0.5000
# Epoch 14/100
# 2/2 [==============================] - 0s 168ms/step - loss: 0.6757 - accuracy: 0.5000 - val_loss: 0.6570 - val_accuracy: 0.5000
# Epoch 15/100
# 2/2 [==============================] - 0s 145ms/step - loss: 0.6748 - accuracy: 0.5000 - val_loss: 0.6560 - val_accuracy: 0.5000
# Epoch 16/100
# 2/2 [==============================] - 0s 122ms/step - loss: 0.6736 - accuracy: 0.5000 - val_loss: 0.6551 - val_accuracy: 0.5000
# Epoch 17/100
# 2/2 [==============================] - 0s 142ms/step - loss: 0.6722 - accuracy: 0.5000 - val_loss: 0.6543 - val_accuracy: 0.5000
# Epoch 18/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6712 - accuracy: 0.5000 - val_loss: 0.6535 - val_accuracy: 0.5000
# Epoch 19/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6700 - accuracy: 0.5000 - val_loss: 0.6528 - val_accuracy: 0.5000
# Epoch 20/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6690 - accuracy: 0.5000 - val_loss: 0.6522 - val_accuracy: 0.5000
# Epoch 21/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6681 - accuracy: 0.5217 - val_loss: 0.6515 - val_accuracy: 0.6875
# Epoch 22/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6669 - accuracy: 0.5870 - val_loss: 0.6509 - val_accuracy: 0.6875
# Epoch 23/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6664 - accuracy: 0.5870 - val_loss: 0.6504 - val_accuracy: 0.6875
# Epoch 24/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6656 - accuracy: 0.5870 - val_loss: 0.6499 - val_accuracy: 0.6875
# Epoch 25/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6646 - accuracy: 0.5870 - val_loss: 0.6495 - val_accuracy: 0.6875
# Epoch 26/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6639 - accuracy: 0.5870 - val_loss: 0.6490 - val_accuracy: 0.6875
# Epoch 27/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6631 - accuracy: 0.5870 - val_loss: 0.6485 - val_accuracy: 0.6875
# Epoch 28/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6623 - accuracy: 0.5870 - val_loss: 0.6479 - val_accuracy: 0.6875
# Epoch 29/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6618 - accuracy: 0.5870 - val_loss: 0.6473 - val_accuracy: 0.6875
# Epoch 30/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6611 - accuracy: 0.5870 - val_loss: 0.6468 - val_accuracy: 0.6875
# Epoch 31/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6605 - accuracy: 0.5870 - val_loss: 0.6462 - val_accuracy: 0.6875
# Epoch 32/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.6596 - accuracy: 0.5870 - val_loss: 0.6457 - val_accuracy: 0.6875
# Epoch 33/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6591 - accuracy: 0.5870 - val_loss: 0.6452 - val_accuracy: 0.6875
# Epoch 34/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6586 - accuracy: 0.5870 - val_loss: 0.6446 - val_accuracy: 0.6875
# Epoch 35/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6578 - accuracy: 0.5870 - val_loss: 0.6441 - val_accuracy: 0.6875
# Epoch 36/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6573 - accuracy: 0.5870 - val_loss: 0.6436 - val_accuracy: 0.6875
# Epoch 37/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6566 - accuracy: 0.5870 - val_loss: 0.6431 - val_accuracy: 0.6875
# Epoch 38/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6562 - accuracy: 0.5870 - val_loss: 0.6425 - val_accuracy: 0.6875
# Epoch 39/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6554 - accuracy: 0.5870 - val_loss: 0.6417 - val_accuracy: 0.6875
# Epoch 40/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6547 - accuracy: 0.5870 - val_loss: 0.6410 - val_accuracy: 0.6875
# Epoch 41/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6537 - accuracy: 0.5870 - val_loss: 0.6402 - val_accuracy: 0.6875
# Epoch 42/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.6529 - accuracy: 0.5870 - val_loss: 0.6394 - val_accuracy: 0.6875
# Epoch 43/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6524 - accuracy: 0.5870 - val_loss: 0.6387 - val_accuracy: 0.6875
# Epoch 44/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.6517 - accuracy: 0.5870 - val_loss: 0.6383 - val_accuracy: 0.6875
# Epoch 45/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6513 - accuracy: 0.5870 - val_loss: 0.6379 - val_accuracy: 0.6875
# Epoch 46/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6507 - accuracy: 0.5870 - val_loss: 0.6375 - val_accuracy: 0.6875
# Epoch 47/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6503 - accuracy: 0.5870 - val_loss: 0.6371 - val_accuracy: 0.6875
# Epoch 48/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6499 - accuracy: 0.5870 - val_loss: 0.6366 - val_accuracy: 0.6875
# Epoch 49/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6494 - accuracy: 0.5870 - val_loss: 0.6361 - val_accuracy: 0.6875
# Epoch 50/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6487 - accuracy: 0.5870 - val_loss: 0.6356 - val_accuracy: 0.7188
# Epoch 51/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6483 - accuracy: 0.5870 - val_loss: 0.6351 - val_accuracy: 0.7188
# Epoch 52/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6479 - accuracy: 0.5870 - val_loss: 0.6345 - val_accuracy: 0.7188
# Epoch 53/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6473 - accuracy: 0.5870 - val_loss: 0.6340 - val_accuracy: 0.7188
# Epoch 54/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6468 - accuracy: 0.5870 - val_loss: 0.6335 - val_accuracy: 0.7188
# Epoch 55/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6463 - accuracy: 0.6304 - val_loss: 0.6330 - val_accuracy: 0.8750
# Epoch 56/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6460 - accuracy: 0.7391 - val_loss: 0.6325 - val_accuracy: 0.8750
# Epoch 57/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6453 - accuracy: 0.7391 - val_loss: 0.6321 - val_accuracy: 0.8750
# Epoch 58/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6449 - accuracy: 0.7391 - val_loss: 0.6316 - val_accuracy: 0.8750
# Epoch 59/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6443 - accuracy: 0.7391 - val_loss: 0.6311 - val_accuracy: 0.8750
# Epoch 60/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6441 - accuracy: 0.7391 - val_loss: 0.6307 - val_accuracy: 0.8750
# Epoch 61/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6435 - accuracy: 0.7391 - val_loss: 0.6302 - val_accuracy: 0.8750
# Epoch 62/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6431 - accuracy: 0.7391 - val_loss: 0.6297 - val_accuracy: 0.8750
# Epoch 63/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.6425 - accuracy: 0.7391 - val_loss: 0.6292 - val_accuracy: 0.8750
# Epoch 64/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6421 - accuracy: 0.7391 - val_loss: 0.6286 - val_accuracy: 0.8750
# Epoch 65/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6416 - accuracy: 0.7391 - val_loss: 0.6281 - val_accuracy: 0.8750
# Epoch 66/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6410 - accuracy: 0.7391 - val_loss: 0.6277 - val_accuracy: 0.8750
# Epoch 67/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.6407 - accuracy: 0.7391 - val_loss: 0.6273 - val_accuracy: 0.8750
# Epoch 68/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.6402 - accuracy: 0.7391 - val_loss: 0.6269 - val_accuracy: 0.8750
# Epoch 69/100
# 2/2 [==============================] - 0s 65ms/step - loss: 0.6399 - accuracy: 0.7391 - val_loss: 0.6264 - val_accuracy: 0.8750
# Epoch 70/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6394 - accuracy: 0.7391 - val_loss: 0.6260 - val_accuracy: 0.8750
# Epoch 71/100
# 2/2 [==============================] - 0s 74ms/step - loss: 0.6389 - accuracy: 0.7391 - val_loss: 0.6255 - val_accuracy: 0.8750
# Epoch 72/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.6384 - accuracy: 0.7391 - val_loss: 0.6251 - val_accuracy: 0.8750
# Epoch 73/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.6381 - accuracy: 0.7391 - val_loss: 0.6247 - val_accuracy: 0.8750
# Epoch 74/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.6377 - accuracy: 0.7391 - val_loss: 0.6243 - val_accuracy: 0.8750
# Epoch 75/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.6374 - accuracy: 0.7391 - val_loss: 0.6238 - val_accuracy: 0.8750
# Epoch 76/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6369 - accuracy: 0.7391 - val_loss: 0.6234 - val_accuracy: 0.8750
# Epoch 77/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.6366 - accuracy: 0.7391 - val_loss: 0.6230 - val_accuracy: 0.8750
# Epoch 78/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6362 - accuracy: 0.7391 - val_loss: 0.6225 - val_accuracy: 0.8750
# Epoch 79/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.6358 - accuracy: 0.7391 - val_loss: 0.6221 - val_accuracy: 0.8750
# Epoch 80/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6354 - accuracy: 0.7391 - val_loss: 0.6217 - val_accuracy: 0.8750
# Epoch 81/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.6350 - accuracy: 0.7391 - val_loss: 0.6213 - val_accuracy: 0.8750
# Epoch 82/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.6346 - accuracy: 0.7391 - val_loss: 0.6208 - val_accuracy: 0.8750
# Epoch 83/100
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6341 - accuracy: 0.7391 - val_loss: 0.6204 - val_accuracy: 0.8750
# Epoch 84/100
# 2/2 [==============================] - 0s 52ms/step - loss: 0.6338 - accuracy: 0.7391 - val_loss: 0.6200 - val_accuracy: 0.8750
# Epoch 85/100
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6333 - accuracy: 0.7391 - val_loss: 0.6196 - val_accuracy: 0.8750
# Epoch 86/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6329 - accuracy: 0.7391 - val_loss: 0.6193 - val_accuracy: 0.8750
# Epoch 87/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.6327 - accuracy: 0.7391 - val_loss: 0.6189 - val_accuracy: 0.8750
# Epoch 88/100
# 2/2 [==============================] - 0s 53ms/step - loss: 0.6322 - accuracy: 0.7391 - val_loss: 0.6184 - val_accuracy: 0.8750
# Epoch 89/100
# 2/2 [==============================] - 0s 59ms/step - loss: 0.6319 - accuracy: 0.7391 - val_loss: 0.6180 - val_accuracy: 0.8750
# Epoch 90/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6313 - accuracy: 0.7391 - val_loss: 0.6176 - val_accuracy: 0.8750
# Epoch 91/100
# 2/2 [==============================] - 0s 76ms/step - loss: 0.6309 - accuracy: 0.7391 - val_loss: 0.6174 - val_accuracy: 0.8750
# Epoch 92/100
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6309 - accuracy: 0.7391 - val_loss: 0.6171 - val_accuracy: 0.8750
# Epoch 93/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.6304 - accuracy: 0.7391 - val_loss: 0.6166 - val_accuracy: 0.8750
# Epoch 94/100
# 2/2 [==============================] - 0s 61ms/step - loss: 0.6300 - accuracy: 0.7391 - val_loss: 0.6163 - val_accuracy: 0.8750
# Epoch 95/100
# 2/2 [==============================] - 0s 72ms/step - loss: 0.6297 - accuracy: 0.7391 - val_loss: 0.6160 - val_accuracy: 0.8750
# Epoch 96/100
# 2/2 [==============================] - 0s 55ms/step - loss: 0.6294 - accuracy: 0.7391 - val_loss: 0.6157 - val_accuracy: 0.8750
# Epoch 97/100
# 2/2 [==============================] - 0s 74ms/step - loss: 0.6290 - accuracy: 0.7391 - val_loss: 0.6154 - val_accuracy: 0.8750
# Epoch 98/100
# 2/2 [==============================] - 0s 71ms/step - loss: 0.6287 - accuracy: 0.7391 - val_loss: 0.6151 - val_accuracy: 0.8750
# Epoch 99/100
# 2/2 [==============================] - 0s 66ms/step - loss: 0.6284 - accuracy: 0.7391 - val_loss: 0.6147 - val_accuracy: 0.8750
# Epoch 100/100
# 2/2 [==============================] - 0s 64ms/step - loss: 0.6281 - accuracy: 0.7391 - val_loss: 0.6143 - val_accuracy: 0.8750
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 3)                 12
#
#  dense_22 (Dense)            (None, 10)                40
#
#  dense_23 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 63 (252.00 Byte)
# Trainable params: 63 (252.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
acc = h_cnn.history['accuracy']
val_acc = h_cnn.history['val_accuracy']

loss = h_cnn.history['loss']
val_loss = h_cnn.history['val_loss']


plt.figure(figsize=(10, 10))

plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy', color='r')
plt.plot(val_acc, label='Validation Accuracy', color='b')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(loc='lower right', fontsize=13)
plt.ylabel('Accuracy', fontsize=16, weight='bold')
plt.title('CNN - Training & Validation Acc.', fontsize=16, weight='bold')


plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss', color='g')
plt.plot(val_loss, label='Validation Loss', color='y')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(loc='upper right', fontsize=10)
plt.ylabel('Cross Entropy', fontsize=10, weight='bold')
plt.title('CNN - Training & Validation Loss', fontsize=15, weight='bold')
plt.xlabel('Epoch', fontsize=8, weight='bold')

plt.show()

import tensorflow as tf
from tensorflow import keras
es=tf.keras.callbacks.EarlyStopping(
    min_delta=0.001,
    patience=10,
    restore_best_weights=True
)

# %%
from sklearn.metrics import classification_report

Y_pred = model_cnn.predict(x_test)
y_pred = np.round(Y_pred)

print(classification_report(y_test, y_pred))
# Out:
# 1/1 [==============================] - 0s 30ms/step
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88        16
#            1       0.88      0.88      0.88        16
#
#     accuracy                           0.88        32
#    macro avg       0.88      0.88      0.88        32
# weighted avg       0.88      0.88      0.88        32

# %%
import itertools
from sklearn.metrics import confusion_matrix
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, weight='bold', fontsize=10)
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, fontsize=10)
    plt.yticks(tick_marks, classes, fontsize=10)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center", fontsize=15, weight='bold',
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label', fontsize=16, weight='bold')
    plt.xlabel('Predicted label', fontsize=16, weight='bold')

cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

plt.figure(figsize=(5, 5))
plot_confusion_matrix(cnf_matrix, classes=['1', '2'], normalize=True,
                      title='MLP - Normalized Confusion Matrix')
plt.grid(False)
plt.show()
# Out:
# Normalized confusion matrix
